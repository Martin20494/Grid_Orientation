# %% [markdown]
# ## Change directory to modules folder

# %%
# Reference: https://stackoverflow.com/questions/15514593/importerror-no-module-named-when-trying-to-run-python-script/15622021#15622021
import sys
sys.path.append(r'G:\Grid_Orientation\LISFLOOD_FP\Modelling\Modules')

# %% [markdown]
# ## Code running

# %% [markdown]
# ### 1. Packages

# %%
from randomisation import random_transformation     # For collecting transformation values
from lidar import download_lidar                    # For downloading LiDAR data
from transformation import get_url                  # For getting url file for transformation command
from demReference import padding_combination, \
                         dem_raster_reference       # For padding calculation and dem reference generation
from transformation import center_calculation       # For center calculation
from execution import *                             # For executing transformed and un-transformed functions

# %% [markdown]
# ### 2. Necessary variables

# %%
# LiDAR number file
num_lidar_file = 0

# LiDAR dataset name
lidar_name = "NZ20_Westport"

# Transformation selection
transform_selection = "c"

# Chunks and processors information
size_of_chunk = 100
size_of_processor = 6

# Discharge file
discharge_filepath = r"S:\\LISFLOOD\\rivers\\river_waikanae_small.csv"

# Time file
time_filepath = r"S:\\LISFLOOD\\times\\time.csv"

# Extracting flowdepth rate (for flowdepth_extraction() function)
flowdepth_rate = 0

# Time to extract flowdepth (for flowdepth_extraction() function)
time_extract = 36

# %%
# Construct a list of boundary -------------------------------------------------------------------------------------------------
resolution = 10
number_pixel_x = 16 * 12  # multiple of 16
number_pixel_y = 16 * 30  # multiple of 16

xmin = 1482750
ymin = 5373000
# ------------------------------------------------------------------------------------------------------------------------------

# Construct a list of boundary -------------------------------------------------------------------------------------------------
# resolution = 10
# number_pixel_x = 16*38                                   # multiple of 16
# number_pixel_y = 16*16                                   # multiple of 16

# xmin = 1767665
# ymin = 5471670
# ------------------------------------------------------------------------------------------------------------------------------

xmax = xmin + resolution * number_pixel_x
ymax = ymin + resolution * number_pixel_y

# Boundary for the area of interest
boundary_1 = [xmin, ymin, xmax, ymax]

# Padding boundary for DEMs (use this boundary to create padding)
addition_2 = 16 * 3
boundary_2 = padding_combination(boundary_1, addition_2)

# Boundary for tiles (use this boundary to download LiDAR)
addition_3 = 16 * 3
boundary_3 = padding_combination(boundary_2, addition_3)

# %%
# %%time
# # Download LiDAR
# download_lidar(boundary_3, "NZ20_Westport", num_lidar_file)

# Reference DEM without padding
dem_raster_reference(transform_selection,
                     resolution, size_of_chunk, size_of_processor,
                     f"lidar_{num_lidar_file}", boundary_1, lidar_name, False)

# Reference DEM with padding
dem_raster_reference(transform_selection,
                     resolution, size_of_chunk, size_of_processor,
                     f"lidar_{num_lidar_file}", boundary_2, lidar_name)

# Calculate coordinates of center point
center_point = center_calculation(transform_selection, True)
center_x = center_point[0]                     # Extract x coordinate of center point
center_y = center_point[1]                     # Extract y coordinate of center point

# Transformation values
ran_trans = random_transformation(
    1,
    45,
    [0, 90],
    [0, 0],
    [0, 0],
    'uniform',
    True
)

# Get url list file
url_list_file = get_url(num_lidar_file, lidar_name)
# Out:
# Check files in dataset NZ20_Westport
# <Client: 'tcp://127.0.0.1:62411' processes=6 threads=6, memory=63.69 GiB>
# C:\Program Files\Anaconda3\envs\geofabrics40\lib\site-packages\geofabrics\dem.py:426: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   dense_extents = shapely.geometry.MultiPolygon([shapely.geometry.Polygon(polygon.exterior)
# WARNING:rasterio._env:CPLE_AppDefined in Recode from UTF-8 to CP_ACP failed with the error: "Invalid argument".
# WARNING:rasterio._env:CPLE_AppDefined in Recode from UTF-8 to CP_ACP failed with the error: "Invalid argument".
# WARNING:rasterio._env:CPLE_AppDefined in Recode from UTF-8 to CP_ACP failed with the error: "Invalid argument".
# Check files in dataset NZ20_Westport
# <Client: 'tcp://127.0.0.1:62511' processes=6 threads=6, memory=63.69 GiB>
# C:\Program Files\Anaconda3\envs\geofabrics40\lib\site-packages\geofabrics\dem.py:426: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   dense_extents = shapely.geometry.MultiPolygon([shapely.geometry.Polygon(polygon.exterior)
# Wall time: 4min 4s

# %%
# import numpy as np
# np.save(r"S:\LISFLOOD\version_6\7_results\un_combination\uncom_csv\ran_trans6.npy", ran_trans)

# %% [markdown]
# ### 3. Code running

# %%
# Transform tiles
run_simulation(ran_trans,
               transform_selection, num_lidar_file,
               center_x, center_y,
               url_list_file, lidar_name)
# Out:
# *** CLASSIFICATION DICTIONARY --------------------------------------------------
# * Tile 0 - CL2_BR20_2020_1000_3828 ------------------------------
# * Running time of creating dictionaries:                    0.015489176909128825
# ------------------------------
# * Tile 1 - CL2_BR20_2020_1000_3829 ------------------------------
# * Running time of creating dictionaries:                    0.019765170415242513
# ------------------------------
# * Tile 2 - CL2_BR20_2020_1000_3830 ------------------------------
# * Running time of creating dictionaries:                    0.03479387362798055
# ------------------------------
# * Tile 3 - CL2_BR20_2020_1000_3831 ------------------------------
# * Running time of creating dictionaries:                    0.02330431540807088
# ------------------------------
# * Tile 4 - CL2_BR20_2020_1000_3832 ------------------------------
# * Running time of creating dictionaries:                    0.03833784659703573
# ------------------------------
# * Tile 5 - CL2_BR20_2020_1000_3833 ------------------------------
# * Running time of creating dictionaries:                    0.03494096994400024
# ------------------------------
# * Tile 6 - CL2_BR20_2020_1000_3834 ------------------------------
# * Running time of creating dictionaries:                    0.024436811606089275
# ------------------------------
# * Tile 7 - CL2_BR20_2020_1000_3835 ------------------------------
# * Running time of creating dictionaries:                    0.026828062534332276
# ------------------------------
# * Tile 8 - CL2_BR20_2020_1000_3836 ------------------------------
# * Running time of creating dictionaries:                    0.028907012939453126
# ------------------------------
# * Tile 9 - CL2_BR20_2020_1000_3837 ------------------------------
# * Running time of creating dictionaries:                    0.022839860121409098
# ------------------------------
# * Tile 10 - CL2_BR20_2020_1000_3838 ------------------------------
# * Running time of creating dictionaries:                    0.025405474503835044
# ------------------------------
# * Tile 11 - CL2_BR20_2020_1000_3839 ------------------------------
# * Running time of creating dictionaries:                    0.022267083326975506
# ------------------------------
# * Tile 12 - CL2_BR20_2020_1000_3840 ------------------------------
# * Running time of creating dictionaries:                    0.02206575870513916
# ------------------------------
# * Tile 13 - CL2_BR20_2020_1000_3841 ------------------------------
# * Running time of creating dictionaries:                    0.01995115280151367
# ------------------------------
# * Tile 14 - CL2_BR20_2020_1000_3926 ------------------------------
# * Running time of creating dictionaries:                    0.0141000231107076
# ------------------------------
# * Tile 15 - CL2_BR20_2020_1000_3927 ------------------------------
# * Running time of creating dictionaries:                    0.013700572649637859
# ------------------------------
# * Tile 16 - CL2_BR20_2020_1000_3928 ------------------------------
# * Running time of creating dictionaries:                    0.028474883238474528
# ------------------------------
# * Tile 17 - CL2_BR20_2020_1000_3929 ------------------------------
# * Running time of creating dictionaries:                    0.04108691215515137
# ------------------------------
# * Tile 18 - CL2_BR20_2020_1000_3930 ------------------------------
# * Running time of creating dictionaries:                    0.02865711450576782
# ------------------------------
# * Tile 19 - CL2_BR20_2020_1000_3931 ------------------------------
# * Running time of creating dictionaries:                    0.019350985685984295
# ------------------------------
# * Tile 20 - CL2_BR20_2020_1000_3932 ------------------------------
# * Running time of creating dictionaries:                    0.04002778927485148
# ------------------------------
# * Tile 21 - CL2_BR20_2020_1000_3933 ------------------------------
# * Running time of creating dictionaries:                    0.03795108397801717
# ------------------------------
# * Tile 22 - CL2_BR20_2020_1000_3934 ------------------------------
# * Running time of creating dictionaries:                    0.0395365317662557
# ------------------------------
# * Tile 23 - CL2_BR20_2020_1000_3935 ------------------------------
# * Running time of creating dictionaries:                    0.0374405304590861
# ------------------------------
# * Tile 24 - CL2_BR20_2020_1000_3936 ------------------------------
# * Running time of creating dictionaries:                    0.034656953811645505
# ------------------------------
# * Tile 25 - CL2_BR20_2020_1000_3937 ------------------------------
# * Running time of creating dictionaries:                    0.04216820398966471
# ------------------------------
# * Tile 26 - CL2_BR20_2020_1000_3938 ------------------------------
# * Running time of creating dictionaries:                    0.0343040148417155
# ------------------------------
# * Tile 27 - CL2_BR20_2020_1000_3939 ------------------------------
# * Running time of creating dictionaries:                    0.03061360518137614
# ------------------------------
# * Tile 28 - CL2_BR20_2020_1000_3940 ------------------------------
# * Running time of creating dictionaries:                    0.03604058424631754
# ------------------------------
# * Tile 29 - CL2_BR20_2020_1000_3941 ------------------------------
# * Running time of creating dictionaries:                    0.04183546702067057
# ------------------------------
# * Tile 30 - CL2_BR20_2020_1000_4025 ------------------------------
# * Running time of creating dictionaries:                    0.017139852046966553
# ------------------------------
# * Tile 31 - CL2_BR20_2020_1000_4026 ------------------------------
# * Running time of creating dictionaries:                    0.021666773160298667
# ------------------------------
# * Tile 32 - CL2_BR20_2020_1000_4027 ------------------------------
# * Running time of creating dictionaries:                    0.03870052893956502
# ------------------------------
# * Tile 33 - CL2_BR20_2020_1000_4028 ------------------------------
# * Running time of creating dictionaries:                    0.03492307265599569
# ------------------------------
# * Tile 34 - CL2_BR20_2020_1000_4029 ------------------------------
# * Running time of creating dictionaries:                    0.03038006623586019
# ------------------------------
# * Tile 35 - CL2_BR20_2020_1000_4030 ------------------------------
# * Running time of creating dictionaries:                    0.037441933155059816
# ------------------------------
# * Tile 36 - CL2_BR20_2020_1000_4031 ------------------------------
# * Running time of creating dictionaries:                    0.024452336629231772
# ------------------------------
# * Tile 37 - CL2_BR20_2020_1000_4032 ------------------------------
# * Running time of creating dictionaries:                    0.01801832914352417
# ------------------------------
# * Tile 38 - CL2_BR20_2020_1000_4033 ------------------------------
# * Running time of creating dictionaries:                    0.04029276768366496
# ------------------------------
# * Tile 39 - CL2_BR20_2020_1000_4034 ------------------------------
# * Running time of creating dictionaries:                    0.03370950222015381
# ------------------------------
# * Tile 40 - CL2_BR20_2020_1000_4035 ------------------------------
# * Running time of creating dictionaries:                    0.03713809649149577
# ------------------------------
# * Tile 41 - CL2_BR20_2020_1000_4036 ------------------------------
# * Running time of creating dictionaries:                    0.03788154125213623
# ------------------------------
# * Tile 42 - CL2_BR20_2020_1000_4037 ------------------------------
# * Running time of creating dictionaries:                    0.02665036916732788
# ------------------------------
# * Tile 43 - CL2_BR20_2020_1000_4038 ------------------------------
# * Running time of creating dictionaries:                    0.032096898555755614
# ------------------------------
# * Tile 44 - CL2_BR20_2020_1000_4039 ------------------------------
# * Running time of creating dictionaries:                    0.04007890224456787
# ------------------------------
# * Tile 45 - CL2_BR20_2020_1000_4040 ------------------------------
# * Running time of creating dictionaries:                    0.03678605556488037
# ------------------------------
# * Tile 46 - CL2_BR20_2020_1000_4041 ------------------------------
# * Running time of creating dictionaries:                    0.03821799357732137
# ------------------------------
# * Tile 47 - CL2_BR20_2020_1000_4125 ------------------------------
# * Running time of creating dictionaries:                    0.0315145214398702
# ------------------------------
# * Tile 48 - CL2_BR20_2020_1000_4126 ------------------------------
# * Running time of creating dictionaries:                    0.042387394110361735
# ------------------------------
# * Tile 49 - CL2_BR20_2020_1000_4127 ------------------------------
# * Running time of creating dictionaries:                    0.03690524498621623
# ------------------------------
# * Tile 50 - CL2_BR20_2020_1000_4128 ------------------------------
# * Running time of creating dictionaries:                    0.030074683825174968
# ------------------------------
# * Tile 51 - CL2_BR20_2020_1000_4129 ------------------------------
# * Running time of creating dictionaries:                    0.04005950689315796
# ------------------------------
# * Tile 52 - CL2_BR20_2020_1000_4130 ------------------------------
# * Running time of creating dictionaries:                    0.037582866350809735
# ------------------------------
# * Tile 53 - CL2_BR20_2020_1000_4131 ------------------------------
# * Running time of creating dictionaries:                    0.038430460294087726
# ------------------------------
# * Tile 54 - CL2_BR20_2020_1000_4132 ------------------------------
# * Running time of creating dictionaries:                    0.030385382970174155
# ------------------------------
# * Tile 55 - CL2_BR20_2020_1000_4133 ------------------------------
# * Running time of creating dictionaries:                    0.03306228717168172
# ------------------------------
# * Tile 56 - CL2_BR20_2020_1000_4134 ------------------------------
# * Running time of creating dictionaries:                    0.0417547861735026
# ------------------------------
# * Tile 57 - CL2_BR20_2020_1000_4135 ------------------------------
# * Running time of creating dictionaries:                    0.04045121272404988
# ------------------------------
# * Tile 58 - CL2_BR20_2020_1000_4136 ------------------------------
# * Running time of creating dictionaries:                    0.03191696008046468
# ------------------------------
# * Tile 59 - CL2_BR20_2020_1000_4137 ------------------------------
# * Running time of creating dictionaries:                    0.039915092786153156
# ------------------------------
# * Tile 60 - CL2_BR20_2020_1000_4138 ------------------------------
# * Running time of creating dictionaries:                    0.04074165821075439
# ------------------------------
# * Tile 61 - CL2_BR20_2020_1000_4139 ------------------------------
# * Running time of creating dictionaries:                    0.03553075393040975
# ------------------------------
# * Tile 62 - CL2_BR20_2020_1000_4140 ------------------------------
# * Running time of creating dictionaries:                    0.04180890719095866
# ------------------------------
# * Tile 63 - CL2_BR20_2020_1000_4141 ------------------------------
# * Running time of creating dictionaries:                    0.04697955846786499
# ------------------------------
# * Tile 64 - CL2_BR20_2020_1000_4225 ------------------------------
# * Running time of creating dictionaries:                    0.054467674096425375
# ------------------------------
# * Tile 65 - CL2_BR20_2020_1000_4226 ------------------------------
# * Running time of creating dictionaries:                    0.03525973955790202
# ------------------------------
# * Tile 66 - CL2_BR20_2020_1000_4227 ------------------------------
# * Running time of creating dictionaries:                    0.03883376121520996
# ------------------------------
# * Tile 67 - CL2_BR20_2020_1000_4228 ------------------------------
# * Running time of creating dictionaries:                    0.04426347017288208
# ------------------------------
# * Tile 68 - CL2_BR20_2020_1000_4229 ------------------------------
# * Running time of creating dictionaries:                    0.03402154843012492
# ------------------------------
# * Tile 69 - CL2_BR20_2020_1000_4230 ------------------------------
# * Running time of creating dictionaries:                    0.04463161627451579
# ------------------------------
# * Tile 70 - CL2_BR20_2020_1000_4231 ------------------------------
# * Running time of creating dictionaries:                    0.038015083471934004
# ------------------------------
# * Tile 71 - CL2_BR20_2020_1000_4232 ------------------------------
# * Running time of creating dictionaries:                    0.01950711409250895
# ------------------------------
# * Tile 72 - CL2_BR20_2020_1000_4233 ------------------------------
# * Running time of creating dictionaries:                    0.04097641309102376
# ------------------------------
# * Tile 73 - CL2_BR20_2020_1000_4234 ------------------------------
# * Running time of creating dictionaries:                    0.034424575169881184
# ------------------------------
# * Tile 74 - CL2_BR20_2020_1000_4235 ------------------------------
# * Running time of creating dictionaries:                    0.03798547188440959
# ------------------------------
# * Tile 75 - CL2_BR20_2020_1000_4236 ------------------------------
# * Running time of creating dictionaries:                    0.04397288958231608
# ------------------------------
# * Tile 76 - CL2_BR20_2020_1000_4237 ------------------------------
# * Running time of creating dictionaries:                    0.044614748160044355
# ------------------------------
# * Tile 77 - CL2_BR20_2020_1000_4238 ------------------------------
# * Running time of creating dictionaries:                    0.03931366602579753
# ------------------------------
# * Tile 78 - CL2_BR20_2020_1000_4239 ------------------------------
# * Running time of creating dictionaries:                    0.043731836477915446
# ------------------------------
# * Tile 79 - CL2_BR20_2020_1000_4240 ------------------------------
# * Running time of creating dictionaries:                    0.03949579397837321
# ------------------------------
# * Tile 80 - CL2_BR20_2020_1000_4241 ------------------------------
# * Running time of creating dictionaries:                    0.04087328910827637
# ------------------------------
# * Tile 81 - CL2_BR20_2020_1000_4325 ------------------------------
# * Running time of creating dictionaries:                    0.03829105695088705
# ------------------------------
# * Tile 82 - CL2_BR20_2020_1000_4326 ------------------------------
# * Running time of creating dictionaries:                    0.04013065497080485
# ------------------------------
# * Tile 83 - CL2_BR20_2020_1000_4327 ------------------------------
# * Running time of creating dictionaries:                    0.039781463146209714
# ------------------------------
# * Tile 84 - CL2_BR20_2020_1000_4328 ------------------------------
# * Running time of creating dictionaries:                    0.037891570727030435
# ------------------------------
# * Tile 85 - CL2_BR20_2020_1000_4329 ------------------------------
# * Running time of creating dictionaries:                    0.03913139502207438
# ------------------------------
# * Tile 86 - CL2_BR20_2020_1000_4330 ------------------------------
# * Running time of creating dictionaries:                    0.042596367994944255
# ------------------------------
# * Tile 87 - CL2_BR20_2020_1000_4331 ------------------------------
# * Running time of creating dictionaries:                    0.0337793231010437
# ------------------------------
# * Tile 88 - CL2_BR20_2020_1000_4332 ------------------------------
# * Running time of creating dictionaries:                    0.025981024901072184
# ------------------------------
# * Tile 89 - CL2_BR20_2020_1000_4333 ------------------------------
# * Running time of creating dictionaries:                    0.039982926845550534
# ------------------------------
# * Tile 90 - CL2_BR20_2020_1000_4334 ------------------------------
# * Running time of creating dictionaries:                    0.038425262769063315
# ------------------------------
# * Tile 91 - CL2_BR20_2020_1000_4335 ------------------------------
# * Running time of creating dictionaries:                    0.040841702620188394
# ------------------------------
# * Tile 92 - CL2_BR20_2020_1000_4336 ------------------------------
# * Running time of creating dictionaries:                    0.03969381252924601
# ------------------------------
# * Tile 93 - CL2_BR20_2020_1000_4337 ------------------------------
# * Running time of creating dictionaries:                    0.04016234874725342
# ------------------------------
# * Tile 94 - CL2_BR20_2020_1000_4338 ------------------------------
# * Running time of creating dictionaries:                    0.045720104376475015
# ------------------------------
# * Tile 95 - CL2_BR20_2020_1000_4339 ------------------------------
# * Running time of creating dictionaries:                    0.042208945751190184
# ------------------------------
# * Tile 96 - CL2_BR20_2020_1000_4340 ------------------------------
# * Running time of creating dictionaries:                    0.042943350474039715
# ------------------------------
# * Tile 97 - CL2_BR20_2020_1000_4341 ------------------------------
# * Running time of creating dictionaries:                    0.04212819735209147
# ------------------------------
# * Tile 98 - CL2_BR20_2020_1000_4425 ------------------------------
# * Running time of creating dictionaries:                    0.04057636658350627
# ------------------------------
# * Tile 99 - CL2_BR20_2020_1000_4426 ------------------------------
# * Running time of creating dictionaries:                    0.029551156361897788
# ------------------------------
# * Tile 100 - CL2_BR20_2020_1000_4427 ------------------------------
# * Running time of creating dictionaries:                    0.023852558930714925
# ------------------------------
# * Tile 101 - CL2_BR20_2020_1000_4428 ------------------------------
# * Running time of creating dictionaries:                    0.036758136749267575
# ------------------------------
# * Tile 102 - CL2_BR20_2020_1000_4429 ------------------------------
# * Running time of creating dictionaries:                    0.03469856182734172
# ------------------------------
# * Tile 103 - CL2_BR20_2020_1000_4430 ------------------------------
# * Running time of creating dictionaries:                    0.03623830080032349
# ------------------------------
# * Tile 104 - CL2_BR20_2020_1000_4431 ------------------------------
# * Running time of creating dictionaries:                    0.03992230892181396
# ------------------------------
# * Tile 105 - CL2_BR20_2020_1000_4432 ------------------------------
# * Running time of creating dictionaries:                    0.03109714190165202
# ------------------------------
# * Tile 106 - CL2_BR20_2020_1000_4433 ------------------------------
# * Running time of creating dictionaries:                    0.029942687352498373
# ------------------------------
# * Tile 107 - CL2_BR20_2020_1000_4434 ------------------------------
# * Running time of creating dictionaries:                    0.046225269635518394
# ------------------------------
# * Tile 108 - CL2_BR20_2020_1000_4435 ------------------------------
# * Running time of creating dictionaries:                    0.04566963911056519
# ------------------------------
# * Tile 109 - CL2_BR20_2020_1000_4436 ------------------------------
# * Running time of creating dictionaries:                    0.0452932874361674
# ------------------------------
# * Tile 110 - CL2_BR20_2020_1000_4437 ------------------------------
# * Running time of creating dictionaries:                    0.04429897467295329
# ------------------------------
# * Tile 111 - CL2_BR20_2020_1000_4438 ------------------------------
# * Running time of creating dictionaries:                    0.03897149960199992
# ------------------------------
# * Tile 112 - CL2_BR20_2020_1000_4439 ------------------------------
# * Running time of creating dictionaries:                    0.046481160322825114
# ------------------------------
# * Tile 113 - CL2_BR20_2020_1000_4440 ------------------------------
# * Running time of creating dictionaries:                    0.046539668242136636
# ------------------------------
# * Tile 114 - CL2_BR20_2020_1000_4441 ------------------------------
# * Running time of creating dictionaries:                    0.0332035223642985
# ------------------------------
# * Tile 115 - CL2_BR20_2020_1000_4525 ------------------------------
# * Running time of creating dictionaries:                    0.04018454949061076
# ------------------------------
# * Tile 116 - CL2_BR20_2020_1000_4526 ------------------------------
# * Running time of creating dictionaries:                    0.03200873136520386
# ------------------------------
# * Tile 117 - CL2_BR20_2020_1000_4527 ------------------------------
# * Running time of creating dictionaries:                    0.03214476505915324
# ------------------------------
# * Tile 118 - CL2_BR20_2020_1000_4528 ------------------------------
# * Running time of creating dictionaries:                    0.028639264901479087
# ------------------------------
# * Tile 119 - CL2_BR20_2020_1000_4529 ------------------------------
# * Running time of creating dictionaries:                    0.0365338126818339
# ------------------------------
# * Tile 120 - CL2_BR20_2020_1000_4530 ------------------------------
# * Running time of creating dictionaries:                    0.03836601972579956
# ------------------------------
# * Tile 121 - CL2_BR20_2020_1000_4531 ------------------------------
# * Running time of creating dictionaries:                    0.031024996439615884
# ------------------------------
# * Tile 122 - CL2_BR20_2020_1000_4532 ------------------------------
# * Running time of creating dictionaries:                    0.03962543805440267
# ------------------------------
# * Tile 123 - CL2_BR20_2020_1000_4533 ------------------------------
# * Running time of creating dictionaries:                    0.03525672356287638
# ------------------------------
# * Tile 124 - CL2_BR20_2020_1000_4534 ------------------------------
# * Running time of creating dictionaries:                    0.03386229674021403
# ------------------------------
# * Tile 125 - CL2_BR20_2020_1000_4535 ------------------------------
# * Running time of creating dictionaries:                    0.045973714192708334
# ------------------------------
# * Tile 126 - CL2_BR20_2020_1000_4536 ------------------------------
# * Running time of creating dictionaries:                    0.045855204264322914
# ------------------------------
# * Tile 127 - CL2_BR20_2020_1000_4537 ------------------------------
# * Running time of creating dictionaries:                    0.04008913040161133
# ------------------------------
# * Tile 128 - CL2_BR20_2020_1000_4538 ------------------------------
# * Running time of creating dictionaries:                    0.051371526718139646
# ------------------------------
# * Tile 129 - CL2_BR20_2020_1000_4539 ------------------------------
# * Running time of creating dictionaries:                    0.03310673236846924
# ------------------------------
# * Tile 130 - CL2_BR20_2020_1000_4540 ------------------------------
# * Running time of creating dictionaries:                    0.037906455993652347
# ------------------------------
# * Tile 131 - CL2_BR20_2020_1000_4541 ------------------------------
# * Running time of creating dictionaries:                    0.04993247191111247
# ------------------------------
# * Tile 132 - CL2_BR20_2020_1000_4625 ------------------------------
# * Running time of creating dictionaries:                    0.03598818778991699
# ------------------------------
# * Tile 133 - CL2_BR20_2020_1000_4626 ------------------------------
# * Running time of creating dictionaries:                    0.0355804721514384
# ------------------------------
# * Tile 134 - CL2_BR20_2020_1000_4627 ------------------------------
# * Running time of creating dictionaries:                    0.030692648887634278
# ------------------------------
# * Tile 135 - CL2_BR20_2020_1000_4628 ------------------------------
# * Running time of creating dictionaries:                    0.038988558451334636
# ------------------------------
# * Tile 136 - CL2_BR20_2020_1000_4629 ------------------------------
# * Running time of creating dictionaries:                    0.03421106338500977
# ------------------------------
# * Tile 137 - CL2_BR20_2020_1000_4630 ------------------------------
# * Running time of creating dictionaries:                    0.03323814868927002
# ------------------------------
# * Tile 138 - CL2_BR20_2020_1000_4631 ------------------------------
# * Running time of creating dictionaries:                    0.043590470155080156
# ------------------------------
# * Tile 139 - CL2_BR20_2020_1000_4632 ------------------------------
# * Running time of creating dictionaries:                    0.04294374386469523
# ------------------------------
# * Tile 140 - CL2_BR20_2020_1000_4633 ------------------------------
# * Running time of creating dictionaries:                    0.0387563427289327
# ------------------------------
# * Tile 141 - CL2_BR20_2020_1000_4634 ------------------------------
# * Running time of creating dictionaries:                    0.034433003266652426
# ------------------------------
# * Tile 142 - CL2_BR20_2020_1000_4635 ------------------------------
# * Running time of creating dictionaries:                    0.047487874825795494
# ------------------------------
# * Tile 143 - CL2_BR20_2020_1000_4636 ------------------------------
# * Running time of creating dictionaries:                    0.044215059280395506
# ------------------------------
# * Tile 144 - CL2_BR20_2020_1000_4637 ------------------------------
# * Running time of creating dictionaries:                    0.05146730343500773
# ------------------------------
# * Tile 145 - CL2_BR20_2020_1000_4638 ------------------------------
# * Running time of creating dictionaries:                    0.03434900840123494
# ------------------------------
# * Tile 146 - CL2_BR20_2020_1000_4639 ------------------------------
# * Running time of creating dictionaries:                    0.04901223580042521
# ------------------------------
# * Tile 147 - CL2_BR20_2020_1000_4640 ------------------------------
# * Running time of creating dictionaries:                    0.04991085529327392
# ------------------------------
# * Tile 148 - CL2_BR20_2020_1000_4641 ------------------------------
# * Running time of creating dictionaries:                    0.04790865977605184
# ------------------------------
# * Tile 149 - CL2_BR20_2020_1000_4725 ------------------------------
# * Running time of creating dictionaries:                    0.031226058801015217
# ------------------------------
# * Tile 150 - CL2_BR20_2020_1000_4726 ------------------------------
# * Running time of creating dictionaries:                    0.03155694007873535
# ------------------------------
# * Tile 151 - CL2_BR20_2020_1000_4727 ------------------------------
# * Running time of creating dictionaries:                    0.038829461733500166
# ------------------------------
# * Tile 152 - CL2_BR20_2020_1000_4728 ------------------------------
# * Running time of creating dictionaries:                    0.029414816697438558
# ------------------------------
# * Tile 153 - CL2_BR20_2020_1000_4729 ------------------------------
# * Running time of creating dictionaries:                    0.03650132815043131
# ------------------------------
# * Tile 154 - CL2_BR20_2020_1000_4730 ------------------------------
# * Running time of creating dictionaries:                    0.0415075421333313
# ------------------------------
# * Tile 155 - CL2_BR20_2020_1000_4731 ------------------------------
# * Running time of creating dictionaries:                    0.040521013736724856
# ------------------------------
# * Tile 156 - CL2_BR20_2020_1000_4732 ------------------------------
# * Running time of creating dictionaries:                    0.039672382672627765
# ------------------------------
# * Tile 157 - CL2_BR20_2020_1000_4733 ------------------------------
# * Running time of creating dictionaries:                    0.046526432037353516
# ------------------------------
# * Tile 158 - CL2_BR20_2020_1000_4734 ------------------------------
# * Running time of creating dictionaries:                    0.028939247131347656
# ------------------------------
# * Tile 159 - CL2_BR20_2020_1000_4735 ------------------------------
# * Running time of creating dictionaries:                    0.04332511822382609
# ------------------------------
# * Tile 160 - CL2_BR20_2020_1000_4736 ------------------------------
# * Running time of creating dictionaries:                    0.041541155179341635
# ------------------------------
# * Tile 161 - CL2_BR20_2020_1000_4737 ------------------------------
# * Running time of creating dictionaries:                    0.031353771686553955
# ------------------------------
# * Tile 162 - CL2_BR20_2020_1000_4738 ------------------------------
# * Running time of creating dictionaries:                    0.035755523045857746
# ------------------------------
# * Tile 163 - CL2_BR20_2020_1000_4739 ------------------------------
# * Running time of creating dictionaries:                    0.04440315167109172
# ------------------------------
# * Tile 164 - CL2_BR20_2020_1000_4740 ------------------------------
# * Running time of creating dictionaries:                    0.054111953576405844
# ------------------------------
# * Tile 165 - CL2_BR20_2020_1000_4741 ------------------------------
# * Running time of creating dictionaries:                    0.03353308041890462
# ------------------------------
# * Tile 166 - CL2_BR20_2020_1000_4825 ------------------------------
# * Running time of creating dictionaries:                    0.0409002145131429
# ------------------------------
# * Tile 167 - CL2_BR20_2020_1000_4826 ------------------------------
# * Running time of creating dictionaries:                    0.03850796620051066
# ------------------------------
# * Tile 168 - CL2_BR20_2020_1000_4827 ------------------------------
# * Running time of creating dictionaries:                    0.027315994103749592
# ------------------------------
# * Tile 169 - CL2_BR20_2020_1000_4828 ------------------------------
# * Running time of creating dictionaries:                    0.04055403868357341
# ------------------------------
# * Tile 170 - CL2_BR20_2020_1000_4829 ------------------------------
# * Running time of creating dictionaries:                    0.042637336254119876
# ------------------------------
# * Tile 171 - CL2_BR20_2020_1000_4830 ------------------------------
# * Running time of creating dictionaries:                    0.0464327335357666
# ------------------------------
# * Tile 172 - CL2_BR20_2020_1000_4831 ------------------------------
# * Running time of creating dictionaries:                    0.047410861651102705
# ------------------------------
# * Tile 173 - CL2_BR20_2020_1000_4832 ------------------------------
# * Running time of creating dictionaries:                    0.04432588815689087
# ------------------------------
# * Tile 174 - CL2_BR20_2020_1000_4833 ------------------------------
# * Running time of creating dictionaries:                    0.03723201751708984
# ------------------------------
# * Tile 175 - CL2_BR20_2020_1000_4834 ------------------------------
# * Running time of creating dictionaries:                    0.05497631629308065
# ------------------------------
# * Tile 176 - CL2_BR20_2020_1000_4835 ------------------------------
# * Running time of creating dictionaries:                    0.035507035255432126
# ------------------------------
# * Tile 177 - CL2_BR20_2020_1000_4836 ------------------------------
# * Running time of creating dictionaries:                    0.03178889751434326
# ------------------------------
# * Tile 178 - CL2_BR20_2020_1000_4837 ------------------------------
# * Running time of creating dictionaries:                    0.03636168241500855
# ------------------------------
# * Tile 179 - CL2_BR20_2020_1000_4838 ------------------------------
# * Running time of creating dictionaries:                    0.031066771348317465
# ------------------------------
# * Tile 180 - CL2_BR20_2020_1000_4839 ------------------------------
# * Running time of creating dictionaries:                    0.04530655145645142
# ------------------------------
# * Tile 181 - CL2_BR20_2020_1000_4840 ------------------------------
# * Running time of creating dictionaries:                    0.042685651779174806
# ------------------------------
# * Tile 182 - CL2_BR20_2020_1000_4841 ------------------------------
# * Running time of creating dictionaries:                    0.03432375987370809
# ------------------------------
# * Running time of whole dictionary generation process:      6.729123743375142
# ==========================================================================================
#
#
# *** COORDINATE DICTIONARY --------------------------------------------------
# * Tile 0 - CL2_BR20_2020_1000_3828 ------------------------------
# * Running time of creating dictionaries:                    0.014457599322001139
# ------------------------------
# * Tile 1 - CL2_BR20_2020_1000_3829 ------------------------------
# * Running time of creating dictionaries:                    0.0190472682317098
# ------------------------------
# * Tile 2 - CL2_BR20_2020_1000_3830 ------------------------------
# * Running time of creating dictionaries:                    0.03434091011683146
# ------------------------------
# * Tile 3 - CL2_BR20_2020_1000_3831 ------------------------------
# * Running time of creating dictionaries:                    0.022647432486216226
# ------------------------------
# * Tile 4 - CL2_BR20_2020_1000_3832 ------------------------------
# * Running time of creating dictionaries:                    0.03753306070963542
# ------------------------------
# * Tile 5 - CL2_BR20_2020_1000_3833 ------------------------------
# * Running time of creating dictionaries:                    0.0332446297009786
# ------------------------------
# * Tile 6 - CL2_BR20_2020_1000_3834 ------------------------------
# * Running time of creating dictionaries:                    0.0229812224706014
# ------------------------------
# * Tile 7 - CL2_BR20_2020_1000_3835 ------------------------------
# * Running time of creating dictionaries:                    0.025757316748301187
# ------------------------------
# * Tile 8 - CL2_BR20_2020_1000_3836 ------------------------------
# * Running time of creating dictionaries:                    0.027520191669464112
# ------------------------------
# * Tile 9 - CL2_BR20_2020_1000_3837 ------------------------------
# * Running time of creating dictionaries:                    0.022584180037180584
# ------------------------------
# * Tile 10 - CL2_BR20_2020_1000_3838 ------------------------------
# * Running time of creating dictionaries:                    0.024510339895884196
# ------------------------------
# * Tile 11 - CL2_BR20_2020_1000_3839 ------------------------------
# * Running time of creating dictionaries:                    0.021174609661102295
# ------------------------------
# * Tile 12 - CL2_BR20_2020_1000_3840 ------------------------------
# * Running time of creating dictionaries:                    0.021676286061604818
# ------------------------------
# * Tile 13 - CL2_BR20_2020_1000_3841 ------------------------------
# * Running time of creating dictionaries:                    0.018276707331339518
# ------------------------------
# * Tile 14 - CL2_BR20_2020_1000_3926 ------------------------------
# * Running time of creating dictionaries:                    0.013227880001068115
# ------------------------------
# * Tile 15 - CL2_BR20_2020_1000_3927 ------------------------------
# * Running time of creating dictionaries:                    0.012985384464263916
# ------------------------------
# * Tile 16 - CL2_BR20_2020_1000_3928 ------------------------------
# * Running time of creating dictionaries:                    0.02805190086364746
# ------------------------------
# * Tile 17 - CL2_BR20_2020_1000_3929 ------------------------------
# * Running time of creating dictionaries:                    0.04067768255869548
# ------------------------------
# * Tile 18 - CL2_BR20_2020_1000_3930 ------------------------------
# * Running time of creating dictionaries:                    0.028058775266011558
# ------------------------------
# * Tile 19 - CL2_BR20_2020_1000_3931 ------------------------------
# * Running time of creating dictionaries:                    0.01904202699661255
# ------------------------------
# * Tile 20 - CL2_BR20_2020_1000_3932 ------------------------------
# * Running time of creating dictionaries:                    0.040177762508392334
# ------------------------------
# * Tile 21 - CL2_BR20_2020_1000_3933 ------------------------------
# * Running time of creating dictionaries:                    0.03719195127487183
# ------------------------------
# * Tile 22 - CL2_BR20_2020_1000_3934 ------------------------------
# * Running time of creating dictionaries:                    0.039180819193522134
# ------------------------------
# * Tile 23 - CL2_BR20_2020_1000_3935 ------------------------------
# * Running time of creating dictionaries:                    0.03680151700973511
# ------------------------------
# * Tile 24 - CL2_BR20_2020_1000_3936 ------------------------------
# * Running time of creating dictionaries:                    0.03388401667277018
# ------------------------------
# * Tile 25 - CL2_BR20_2020_1000_3937 ------------------------------
# * Running time of creating dictionaries:                    0.04158632755279541
# ------------------------------
# * Tile 26 - CL2_BR20_2020_1000_3938 ------------------------------
# * Running time of creating dictionaries:                    0.03503423134485881
# ------------------------------
# * Tile 27 - CL2_BR20_2020_1000_3939 ------------------------------
# * Running time of creating dictionaries:                    0.03053958813349406
# ------------------------------
# * Tile 28 - CL2_BR20_2020_1000_3940 ------------------------------
# * Running time of creating dictionaries:                    0.0350371519724528
# ------------------------------
# * Tile 29 - CL2_BR20_2020_1000_3941 ------------------------------
# * Running time of creating dictionaries:                    0.04070988893508911
# ------------------------------
# * Tile 30 - CL2_BR20_2020_1000_4025 ------------------------------
# * Running time of creating dictionaries:                    0.01668030023574829
# ------------------------------
# * Tile 31 - CL2_BR20_2020_1000_4026 ------------------------------
# * Running time of creating dictionaries:                    0.021216344833374024
# ------------------------------
# * Tile 32 - CL2_BR20_2020_1000_4027 ------------------------------
# * Running time of creating dictionaries:                    0.03752967119216919
# ------------------------------
# * Tile 33 - CL2_BR20_2020_1000_4028 ------------------------------
# * Running time of creating dictionaries:                    0.03487472931543986
# ------------------------------
# * Tile 34 - CL2_BR20_2020_1000_4029 ------------------------------
# * Running time of creating dictionaries:                    0.030416770776112875
# ------------------------------
# * Tile 35 - CL2_BR20_2020_1000_4030 ------------------------------
# * Running time of creating dictionaries:                    0.03743357261021932
# ------------------------------
# * Tile 36 - CL2_BR20_2020_1000_4031 ------------------------------
# * Running time of creating dictionaries:                    0.024632680416107177
# ------------------------------
# * Tile 37 - CL2_BR20_2020_1000_4032 ------------------------------
# * Running time of creating dictionaries:                    0.017447253068288166
# ------------------------------
# * Tile 38 - CL2_BR20_2020_1000_4033 ------------------------------
# * Running time of creating dictionaries:                    0.04025936524073283
# ------------------------------
# * Tile 39 - CL2_BR20_2020_1000_4034 ------------------------------
# * Running time of creating dictionaries:                    0.033660860856374104
# ------------------------------
# * Tile 40 - CL2_BR20_2020_1000_4035 ------------------------------
# * Running time of creating dictionaries:                    0.03642958402633667
# ------------------------------
# * Tile 41 - CL2_BR20_2020_1000_4036 ------------------------------
# * Running time of creating dictionaries:                    0.037597791353861494
# ------------------------------
# * Tile 42 - CL2_BR20_2020_1000_4037 ------------------------------
# * Running time of creating dictionaries:                    0.02636930545171102
# ------------------------------
# * Tile 43 - CL2_BR20_2020_1000_4038 ------------------------------
# * Running time of creating dictionaries:                    0.03189930518468221
# ------------------------------
# * Tile 44 - CL2_BR20_2020_1000_4039 ------------------------------
# * Running time of creating dictionaries:                    0.04029841025670369
# ------------------------------
# * Tile 45 - CL2_BR20_2020_1000_4040 ------------------------------
# * Running time of creating dictionaries:                    0.03610429366429647
# ------------------------------
# * Tile 46 - CL2_BR20_2020_1000_4041 ------------------------------
# * Running time of creating dictionaries:                    0.03750007549921672
# ------------------------------
# * Tile 47 - CL2_BR20_2020_1000_4125 ------------------------------
# * Running time of creating dictionaries:                    0.03161936601003011
# ------------------------------
# * Tile 48 - CL2_BR20_2020_1000_4126 ------------------------------
# * Running time of creating dictionaries:                    0.04112728039423625
# ------------------------------
# * Tile 49 - CL2_BR20_2020_1000_4127 ------------------------------
# * Running time of creating dictionaries:                    0.03660672505696615
# ------------------------------
# * Tile 50 - CL2_BR20_2020_1000_4128 ------------------------------
# * Running time of creating dictionaries:                    0.029356082280476887
# ------------------------------
# * Tile 51 - CL2_BR20_2020_1000_4129 ------------------------------
# * Running time of creating dictionaries:                    0.04047437906265259
# ------------------------------
# * Tile 52 - CL2_BR20_2020_1000_4130 ------------------------------
# * Running time of creating dictionaries:                    0.037437713146209715
# ------------------------------
# * Tile 53 - CL2_BR20_2020_1000_4131 ------------------------------
# * Running time of creating dictionaries:                    0.038124640782674156
# ------------------------------
# * Tile 54 - CL2_BR20_2020_1000_4132 ------------------------------
# * Running time of creating dictionaries:                    0.03049046198527018
# ------------------------------
# * Tile 55 - CL2_BR20_2020_1000_4133 ------------------------------
# * Running time of creating dictionaries:                    0.032114946842193605
# ------------------------------
# * Tile 56 - CL2_BR20_2020_1000_4134 ------------------------------
# * Running time of creating dictionaries:                    0.04150071938832601
# ------------------------------
# * Tile 57 - CL2_BR20_2020_1000_4135 ------------------------------
# * Running time of creating dictionaries:                    0.04032744169235229
# ------------------------------
# * Tile 58 - CL2_BR20_2020_1000_4136 ------------------------------
# * Running time of creating dictionaries:                    0.03184324502944946
# ------------------------------
# * Tile 59 - CL2_BR20_2020_1000_4137 ------------------------------
# * Running time of creating dictionaries:                    0.04029942750930786
# ------------------------------
# * Tile 60 - CL2_BR20_2020_1000_4138 ------------------------------
# * Running time of creating dictionaries:                    0.04077504873275757
# ------------------------------
# * Tile 61 - CL2_BR20_2020_1000_4139 ------------------------------
# * Running time of creating dictionaries:                    0.03511772553126017
# ------------------------------
# * Tile 62 - CL2_BR20_2020_1000_4140 ------------------------------
# * Running time of creating dictionaries:                    0.04131750663121541
# ------------------------------
# * Tile 63 - CL2_BR20_2020_1000_4141 ------------------------------
# * Running time of creating dictionaries:                    0.045591827233632407
# ------------------------------
# * Tile 64 - CL2_BR20_2020_1000_4225 ------------------------------
# * Running time of creating dictionaries:                    0.045885173479715984
# ------------------------------
# * Tile 65 - CL2_BR20_2020_1000_4226 ------------------------------
# * Running time of creating dictionaries:                    0.034892714023590087
# ------------------------------
# * Tile 66 - CL2_BR20_2020_1000_4227 ------------------------------
# * Running time of creating dictionaries:                    0.038326338926951094
# ------------------------------
# * Tile 67 - CL2_BR20_2020_1000_4228 ------------------------------
# * Running time of creating dictionaries:                    0.04399492740631104
# ------------------------------
# * Tile 68 - CL2_BR20_2020_1000_4229 ------------------------------
# * Running time of creating dictionaries:                    0.03440730969111125
# ------------------------------
# * Tile 69 - CL2_BR20_2020_1000_4230 ------------------------------
# * Running time of creating dictionaries:                    0.044670605659484865
# ------------------------------
# * Tile 70 - CL2_BR20_2020_1000_4231 ------------------------------
# * Running time of creating dictionaries:                    0.038770576318105064
# ------------------------------
# * Tile 71 - CL2_BR20_2020_1000_4232 ------------------------------
# * Running time of creating dictionaries:                    0.019475809733072915
# ------------------------------
# * Tile 72 - CL2_BR20_2020_1000_4233 ------------------------------
# * Running time of creating dictionaries:                    0.0411664883295695
# ------------------------------
# * Tile 73 - CL2_BR20_2020_1000_4234 ------------------------------
# * Running time of creating dictionaries:                    0.034803680578867596
# ------------------------------
# * Tile 74 - CL2_BR20_2020_1000_4235 ------------------------------
# * Running time of creating dictionaries:                    0.03796523412068685
# ------------------------------
# * Tile 75 - CL2_BR20_2020_1000_4236 ------------------------------
# * Running time of creating dictionaries:                    0.044723641872406
# ------------------------------
# * Tile 76 - CL2_BR20_2020_1000_4237 ------------------------------
# * Running time of creating dictionaries:                    0.045430541038513184
# ------------------------------
# * Tile 77 - CL2_BR20_2020_1000_4238 ------------------------------
# * Running time of creating dictionaries:                    0.039182702700297035
# ------------------------------
# * Tile 78 - CL2_BR20_2020_1000_4239 ------------------------------
# * Running time of creating dictionaries:                    0.04430582920710246
# ------------------------------
# * Tile 79 - CL2_BR20_2020_1000_4240 ------------------------------
# * Running time of creating dictionaries:                    0.04011213779449463
# ------------------------------
# * Tile 80 - CL2_BR20_2020_1000_4241 ------------------------------
# * Running time of creating dictionaries:                    0.040433828035990396
# ------------------------------
# * Tile 81 - CL2_BR20_2020_1000_4325 ------------------------------
# * Running time of creating dictionaries:                    0.03706736167271932
# ------------------------------
# * Tile 82 - CL2_BR20_2020_1000_4326 ------------------------------
# * Running time of creating dictionaries:                    0.04015574057896932
# ------------------------------
# * Tile 83 - CL2_BR20_2020_1000_4327 ------------------------------
# * Running time of creating dictionaries:                    0.03926621675491333
# ...
# * Running time of writing LiDAR tiles into las/laz file:    0.03219167788823445
# * Running time of writing polygon:                          0.0002331852912902832
# * Running time of the whole process:                        0.03285750945409139
# ------------------------------
# * Tile 126 - CL2_BR20_2020_1000_4536 ------------------------------
# * Running time of transforming process:                     0.00044889052708943684
# * Running time of writing LiDAR tiles into las/laz file:    0.031817098458607994
# * Running time of writing polygon:                          0.00019998550415039061
# * Running time of the whole process:                        0.03246597448984782
# ------------------------------
# * Tile 127 - CL2_BR20_2020_1000_4537 ------------------------------
# * Running time of transforming process:                     0.0004156033198038737
# * Running time of writing LiDAR tiles into las/laz file:    0.029387919108072917
# * Running time of writing polygon:                          0.00021613041559855143
# * Running time of the whole process:                        0.030019652843475342
# ------------------------------
# * Tile 128 - CL2_BR20_2020_1000_4538 ------------------------------
# * Running time of transforming process:                     0.0005651275316874186
# * Running time of writing LiDAR tiles into las/laz file:    0.03667671283086141
# * Running time of writing polygon:                          0.0002493580182393392
# * Running time of the whole process:                        0.03749119838078817
# ------------------------------
# * Tile 129 - CL2_BR20_2020_1000_4539 ------------------------------
# * Running time of transforming process:                     0.00038235982259114584
# * Running time of writing LiDAR tiles into las/laz file:    0.022944708665211994
# * Running time of writing polygon:                          0.00015010436375935873
# * Running time of the whole process:                        0.0234771728515625
# ------------------------------
# * Tile 130 - CL2_BR20_2020_1000_4540 ------------------------------
# * Running time of transforming process:                     0.0003658771514892578
# * Running time of writing LiDAR tiles into las/laz file:    0.029562095801035564
# * Running time of writing polygon:                          0.00018286307652791342
# * Running time of the whole process:                        0.030110836029052734
# ------------------------------
# * Tile 131 - CL2_BR20_2020_1000_4541 ------------------------------
# * Running time of transforming process:                     0.00048201878865559896
# * Running time of writing LiDAR tiles into las/laz file:    0.04069250822067261
# * Running time of writing polygon:                          0.0002332290013631185
# * Running time of the whole process:                        0.04140775601069133
# ------------------------------
# * Tile 132 - CL2_BR20_2020_1000_4625 ------------------------------
# * Running time of transforming process:                     0.00036517779032389325
# * Running time of writing LiDAR tiles into las/laz file:    0.023097618420918783
# * Running time of writing polygon:                          0.0001667022705078125
# * Running time of the whole process:                        0.02362949848175049
# ------------------------------
# * Tile 133 - CL2_BR20_2020_1000_4626 ------------------------------
# * Running time of transforming process:                     0.0003655711809794108
# * Running time of writing LiDAR tiles into las/laz file:    0.023239147663116456
# * Running time of writing polygon:                          0.0001662294069925944
# * Running time of the whole process:                        0.02377094825108846
# ------------------------------
# * Tile 134 - CL2_BR20_2020_1000_4627 ------------------------------
# * Running time of transforming process:                     0.0003490447998046875
# * Running time of writing LiDAR tiles into las/laz file:    0.02064761718114217
# * Running time of writing polygon:                          0.00014951229095458985
# * Running time of the whole process:                        0.02114617427190145
# ------------------------------
# * Tile 135 - CL2_BR20_2020_1000_4628 ------------------------------
# * Running time of transforming process:                     0.0003818233807881673
# * Running time of writing LiDAR tiles into las/laz file:    0.02554545005162557
# * Running time of writing polygon:                          0.00021579662958780925
# * Running time of the whole process:                        0.026143070062001547
# ------------------------------
# * Tile 136 - CL2_BR20_2020_1000_4629 ------------------------------
# * Running time of transforming process:                     0.00034911632537841796
# * Running time of writing LiDAR tiles into las/laz file:    0.027923532327016196
# * Running time of writing polygon:                          0.00016623338063557943
# * Running time of the whole process:                        0.028438882033030192
# ------------------------------
# * Tile 137 - CL2_BR20_2020_1000_4630 ------------------------------
# * Running time of transforming process:                     0.0003153284390767415
# * Running time of writing LiDAR tiles into las/laz file:    0.02203045686086019
# * Running time of writing polygon:                          0.00016642014185587565
# * Running time of the whole process:                        0.022512205441792808
# ------------------------------
# * Tile 138 - CL2_BR20_2020_1000_4631 ------------------------------
# * Running time of transforming process:                     0.00044955015182495116
# * Running time of writing LiDAR tiles into las/laz file:    0.030013120174407958
# * Running time of writing polygon:                          0.0002332011858622233
# * Running time of the whole process:                        0.030695871512095133
# ------------------------------
# * Tile 139 - CL2_BR20_2020_1000_4632 ------------------------------
# * Running time of transforming process:                     0.0004153688748677572
# * Running time of writing LiDAR tiles into las/laz file:    0.029415496190389
# * Running time of writing polygon:                          0.0002160310745239258
# * Running time of the whole process:                        0.03004689613978068
# ------------------------------
# * Tile 140 - CL2_BR20_2020_1000_4633 ------------------------------
# * Running time of transforming process:                     0.0003822962443033854
# * Running time of writing LiDAR tiles into las/laz file:    0.029583895206451417
# * Running time of writing polygon:                          0.00019905964533487955
# * Running time of the whole process:                        0.030165251096089682
# ------------------------------
# * Tile 141 - CL2_BR20_2020_1000_4634 ------------------------------
# * Running time of transforming process:                     0.0003495573997497559
# * Running time of writing LiDAR tiles into las/laz file:    0.023732300599416098
# * Running time of writing polygon:                          0.00016621748606363931
# * Running time of the whole process:                        0.024248075485229493
# ------------------------------
# * Tile 142 - CL2_BR20_2020_1000_4635 ------------------------------
# * Running time of transforming process:                     0.0003989418347676595
# * Running time of writing LiDAR tiles into las/laz file:    0.02799994150797526
# * Running time of writing polygon:                          0.00019996960957845052
# * Running time of the whole process:                        0.028598852952321372
# ------------------------------
# * Tile 143 - CL2_BR20_2020_1000_4636 ------------------------------
# * Running time of transforming process:                     0.0004328052202860514
# * Running time of writing LiDAR tiles into las/laz file:    0.02911175092061361
# * Running time of writing polygon:                          0.00021623373031616212
# * Running time of the whole process:                        0.02976078987121582
# ------------------------------
# * Tile 144 - CL2_BR20_2020_1000_4637 ------------------------------
# * Running time of transforming process:                     0.0005158225695292155
# * Running time of writing LiDAR tiles into las/laz file:    0.03559638659159343
# * Running time of writing polygon:                          0.00023269255956013998
# * Running time of the whole process:                        0.03634490172068278
# ------------------------------
# * Tile 145 - CL2_BR20_2020_1000_4638 ------------------------------
# * Running time of transforming process:                     0.00041509071985880533
# * Running time of writing LiDAR tiles into las/laz file:    0.02726931174596151
# * Running time of writing polygon:                          0.00015012820561726887
# * Running time of the whole process:                        0.027834530671437582
# ------------------------------
# * Tile 146 - CL2_BR20_2020_1000_4639 ------------------------------
# * Running time of transforming process:                     0.000465397040049235
# * Running time of writing LiDAR tiles into las/laz file:    0.040645889441172284
# * Running time of writing polygon:                          0.00021683772404988607
# * Running time of the whole process:                        0.041328124205271405
# ------------------------------
# * Tile 147 - CL2_BR20_2020_1000_4640 ------------------------------
# * Running time of transforming process:                     0.0004986882209777832
# * Running time of writing LiDAR tiles into las/laz file:    0.0408272663752238
# * Running time of writing polygon:                          0.00021663904190063476
# * Running time of the whole process:                        0.04154259363810221
# ------------------------------
# * Tile 148 - CL2_BR20_2020_1000_4641 ------------------------------
# * Running time of transforming process:                     0.00048199097315470375
# * Running time of writing LiDAR tiles into las/laz file:    0.04033050537109375
# * Running time of writing polygon:                          0.00021609067916870118
# * Running time of the whole process:                        0.041028587023417155
# ------------------------------
# * Tile 149 - CL2_BR20_2020_1000_4725 ------------------------------
# * Running time of transforming process:                     0.00036568641662597655
# * Running time of writing LiDAR tiles into las/laz file:    0.0212583859761556
# * Running time of writing polygon:                          0.00014913082122802734
# * Running time of the whole process:                        0.021773203214009603
# ------------------------------
# * Tile 150 - CL2_BR20_2020_1000_4726 ------------------------------
# * Running time of transforming process:                     0.00034905672073364257
# * Running time of writing LiDAR tiles into las/laz file:    0.020761764049530028
# * Running time of writing polygon:                          0.00014957189559936524
# * Running time of the whole process:                        0.021260392665863038
# ------------------------------
# * Tile 151 - CL2_BR20_2020_1000_4727 ------------------------------
# * Running time of transforming process:                     0.00039892991383870443
# * Running time of writing LiDAR tiles into las/laz file:    0.025348424911499023
# * Running time of writing polygon:                          0.00021655956904093426
# * Running time of the whole process:                        0.025963914394378663
# ------------------------------
# * Tile 152 - CL2_BR20_2020_1000_4728 ------------------------------
# * Running time of transforming process:                     0.00034911632537841796
# * Running time of writing LiDAR tiles into las/laz file:    0.020586260159810386
# * Running time of writing polygon:                          0.00015010436375935873
# * Running time of the whole process:                        0.021085480848948162
# ------------------------------
# * Tile 153 - CL2_BR20_2020_1000_4729 ------------------------------
# * Running time of transforming process:                     0.0003490289052327474
# * Running time of writing LiDAR tiles into las/laz file:    0.024189317226409913
# * Running time of writing polygon:                          0.0001667022705078125
# * Running time of the whole process:                        0.024705048402150473
# ------------------------------
# * Tile 154 - CL2_BR20_2020_1000_4730 ------------------------------
# * Running time of transforming process:                     0.0005148053169250488
# * Running time of writing LiDAR tiles into las/laz file:    0.02924351692199707
# * Running time of writing polygon:                          0.00023281176884969076
# * Running time of the whole process:                        0.02999113400777181
# ------------------------------
# * Tile 155 - CL2_BR20_2020_1000_4731 ------------------------------
# * Running time of transforming process:                     0.00046542485555013023
# * Running time of writing LiDAR tiles into las/laz file:    0.026192553838094077
# * Running time of writing polygon:                          0.00019994179407755534
# * Running time of the whole process:                        0.026857920487721763
# ------------------------------
# * Tile 156 - CL2_BR20_2020_1000_4732 ------------------------------
# * Running time of transforming process:                     0.0004150708516438802
# * Running time of writing LiDAR tiles into las/laz file:    0.02743979295094808
# * Running time of writing polygon:                          0.00019946495691935222
# * Running time of the whole process:                        0.02805432875951131
# ------------------------------
# * Tile 157 - CL2_BR20_2020_1000_4733 ------------------------------
# * Running time of transforming process:                     0.00046548843383789065
# * Running time of writing LiDAR tiles into las/laz file:    0.03571417331695557
# * Running time of writing polygon:                          0.00023217995961507162
# * Running time of the whole process:                        0.03641184171040853
# ------------------------------
# * Tile 158 - CL2_BR20_2020_1000_4734 ------------------------------
# * Running time of transforming process:                     0.00033244291941324867
# * Running time of writing LiDAR tiles into las/laz file:    0.01920711596806844
# * Running time of writing polygon:                          0.0001501003901163737
# * Running time of the whole process:                        0.019689659277598064
# ------------------------------
# * Tile 159 - CL2_BR20_2020_1000_4735 ------------------------------
# * Running time of transforming process:                     0.0005153218905131022
# * Running time of writing LiDAR tiles into las/laz file:    0.02929005225499471
# * Running time of writing polygon:                          0.00021611849466959636
# * Running time of the whole process:                        0.030021492640177408
# ------------------------------
# * Tile 160 - CL2_BR20_2020_1000_4736 ------------------------------
# * Running time of transforming process:                     0.0004654089609781901
# * Running time of writing LiDAR tiles into las/laz file:    0.02940804958343506
# * Running time of writing polygon:                          0.00019996960957845052
# * Running time of the whole process:                        0.030090034008026123
# ------------------------------
# * Tile 161 - CL2_BR20_2020_1000_4737 ------------------------------
# * Running time of transforming process:                     0.0003652095794677734
# * Running time of writing LiDAR tiles into las/laz file:    0.02233666181564331
# * Running time of writing polygon:                          0.0001495520273844401
# * Running time of the whole process:                        0.022851423422495524
# ------------------------------
# * Tile 162 - CL2_BR20_2020_1000_4738 ------------------------------
# * Running time of transforming process:                     0.00039847691853841144
# * Running time of writing LiDAR tiles into las/laz file:    0.02474899689356486
# * Running time of writing polygon:                          0.00018334388732910156
# * Running time of the whole process:                        0.02533081769943237
# ------------------------------

# %%
# DEM generation
run_dem(ran_trans, transform_selection,
        resolution, size_of_chunk, size_of_processor,
        boundary_2, lidar_name)

# %%
# Values change
run_changing_value(ran_trans, transform_selection, resolution, center_x, center_y)

# %%
# Flood model
run_flood_model(ran_trans, transform_selection, 
                discharge_filepath, time_filepath, resolution, 
                center_x, center_y)

# %%
# Flowdepth extraction
run_flowdepth_extraction(ran_trans, transform_selection, time_extract)

# %%
# Untransformation
run_untransformation(ran_trans, transform_selection, time_extract)
